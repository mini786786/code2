# %%
import nltk
import ssl

# This bypasses the security check for the downloads
ssl._create_default_https_context = ssl._create_unverified_context

# Now try the downloads again
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab') # Adding this one as well just in case
